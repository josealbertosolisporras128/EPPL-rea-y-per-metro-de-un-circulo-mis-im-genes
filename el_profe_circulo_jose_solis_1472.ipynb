# %% [markdown]
# <a href="https://colab.research.google.com/github/josealbertosolisporras128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/blob/main/el_profe_circulo_jose_solis_1472.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### jose solis NL = 51 fecha 25/mar/2026 ⚛
# ---
# # calcular area y perimetro de un circulo
# ---
# ![formulas de circunferencia](https://raw.githubusercontent.com/josealbertosolisporras128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/areacirculo.png)
# ---
# # formula para calcular
# $E=pi*r^2$
# ---
# $P=2*\pi*r$
# ---
# # datos de entrada
# $r$ ?
# ---
# # diagrama de flujo en lucidchart
# ![formulas de circunferencia](https://raw.githubusercontent.com/josealbertosolisporras128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/DF%20Area%20perimetroo%20circulo.png)

# %%
# calcular area y perimetro de un circulo
# variables A, P, r
# formulas A = pi*r^2 y P = 2 * pi * r
# capturar el valor de r
import math
print("calcular area y perimetro de un circulo")
r = float(input("ingrese el valor del radio: "))
A = math.pi*r**2
p = 2*math.pi*r
print("el area del circulo es: ", A)
print("el perimetro del circulo es: ", p)
print("jose solis NL = 51")
# Out:
# calcular area y perimetro de un circulo
# ingrese el valor del radio: 5
# el area del circulo es:  78.53981633974483
# el perimetro del circulo es:  31.41592653589793
# jose solis NL = 51

# %% [markdown]
# # relacion entre codigo y DF en Tldraw
# ![formulas de circunferencia](https://raw.githubusercontent.com/josealbertosolisporras128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/tldar%20DF%20y%20codigo.png)
