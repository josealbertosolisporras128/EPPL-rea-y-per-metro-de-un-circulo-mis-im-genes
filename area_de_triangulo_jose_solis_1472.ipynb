# %% [markdown]
# <a href="https://colab.research.google.com/github/josealbertosolisporras128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/blob/main/area_de_triangulo_jose_solis_1472.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### jose solis NL = 51 fecha 25/mar/2026 ⚛
# ---
# # calcular area de un triangulo
# ---
# ![formulas de circunferencia](https://raw.githubusercontent.com/josealbertosolisporras128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/trianguloarea.webp)
# ---
# # formula para calcular
# $A = \frac{b \cdot h}{2}$
# ---
# # datos de entrada
# $h,
# b$ ?
# ---
# # diagrama de flujo en lucidchart
# ![formulas de circunferencia](https://raw.githubusercontent.com/josealbertosolisporras128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/DF%20area%20trianguloo.png)

# %%
# calcular area de un triangulo rectangulo
# variables A, b, h
# formulas A = (b * h) / 2
# capturar el valor de b y h
import math
print("calcular area de un triangulo rectangulo")
b = float(input("ingrese el valor de la base: "))
h = float(input("ingrese el valor de la altura: "))

A = (b * h) / 2
print("el area del triangulo es: ", A)
print("jose solis NL = 51")
# Out:
# calcular area de un triangulo rectangulo
# ingrese el valor de la base: 10
# ingrese el valor de la altura: 20
# el area del triangulo es:  100.0
# jose solis NL = 51

# %% [markdown]
# # relacion entre codigo y DF en Tldraw
# ![formulas de circunferencia](https://raw.githubusercontent.com/josealbertosolisporras128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/tldraw%20DF%20y%20codigo%20triangulo.png)
